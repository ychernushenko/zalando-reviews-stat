# %%
import csv

with open('datasets/zalando-reviews-FB-release.csv', newline='') as csvfile:
    reviews = csv.DictReader(csvfile, delimiter=',', quotechar='"')
    
    with open("output.csv", "wb") as f:
        fieldnames=['', 'LanguageCode', 'SKU', 'Text', 'Title']
        writer = csv.DictWriter(f, fieldnames=fieldnames)
    
        writer.writeheader()
        for review in reviews:
            if review['LanguageCode'] == "en":
                writer.writerow(review)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c062a1c23861> in <module>()
#       1 import sys
# ----> 2 sys.setdefaultencoding("utf-8")
#       3
#       4 import csv
#       5
#
# AttributeError: 'module' object has no attribute 'setdefaultencoding'

# %%
en_reviews
# Out:
# [{'': '1121',
#   'LanguageCode': 'en',
#   'SKU': 'DU1-m05-0002-03',
#   'Text': 'see above',
#   'Title': 'the shoes are too narrow around the toes'},
#  {'': '1813',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "Fantastic! Shipping was fast. Can't wait to shop here again! These shoes are around one size larger than normal.",
#   'Title': 'great shoes'},
#  {'': '1826',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'Really stylish trainers! I found them to be a bit tight at the beginning. But after a few days they fitted perfectly.',
#   'Title': 'stylish sneakers'},
#  {'': '1860',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'I am very pleased with these shoes, they fit very well and provide great arch support - at the moment this is my favourite pair of shoes',
#   'Title': 'brilliant shoes, simply brilliant shoes'},
#  {'': '1862',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "My first order with Zalando and so far everything has gone well. I'll be back. The shoes, met my expectations despite a little tightness at first - which is normal, I suppose . ",
#   'Title': 'First time'},
#  {'': '1870',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "The shoes really rub on your ankle… I hope it'll get better",
#   'Title': 'Rubs'},
#  {'': '1871',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "I've had these shoes for 10 months and am 100% happy with them. I wore them every 2nd day, sometimes in the slush and, thanks to the shoe cream I used every couple of weeks, they are still in great condition! ",
#   'Title': 'Long term review: GREAT!'},
#  {'': '1872',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "These shoes are AMAZING! I'm very happy…",
#   'Title': 'super'},
#  {'': '1874',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'I am completely satisfied with the shoes, they look great with jeans, but also with "nice" trousers; they look elegant but sporty. I needed a couple of days to get used to them, as it has been a while since I\'ve worn heels… but as I said, they are just great shoes ... and they fit perfectly in my size',
#   'Title': 'A lucky find'},
#  {'': '1875',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "1. the shoes look GREAT. 2. at the moment they aren't too comfortable, really hard on your ankle…but I hope they loosen off",
#   'Title': 'Fantastic shoes with small'},
#  {'': '1876',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "Very comfortable shoes that look great. As the shaft is quite high it is more difficult to put them on than a normal sneaker. The leather feels really soft, but it takes a while to wear them and they're a bit tight around the ankle. The shoes fit as expected, but they come up a bit big, but fit me perfectly as I have wide feet.",
#   'Title': 'very comfy shoes'},
#  {'': '1877',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'The shoes look much lighter online. The leather is actually much darker, what a shame!',
#   'Title': 'darker in reality'},
#  {'': '1878',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'Very stylish trainers which are well made and look great. But a bit unpractical if you want to take them on and off a lot!!!',
#   'Title': 'Boxfresh Eavis'},
#  {'': '1879',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'I had to buy a size smaller. Now they fit perfectly.',
#   'Title': 'Cool shoes'},
#  {'': '1880',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "I read a review before that the shoes come up larger. I can't confirm this as I ordered them in my size.",
#   'Title': 'Fit perfectly'},
#  {'': '1881',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "I am happy, it was really easy and quick, so I'll definitely order again from here.",
#   'Title': 'Satisfied customer'},
#  {'': '1882',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "Awesome shoes, look great and fit very well! Very fast delivery! I'll come again!",
#   'Title': 'The best'},
#  {'': '1883',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'They were one size too big',
#   'Title': 'Size'},
#  {'': '1884',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'the shoes are fine',
#   'Title': 'Boxfresh EAVIS'},
#  {'': '1885',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'the shoes are really hard to put on because of the rounded back.',
#   'Title': 'nice looking but impractical'},
#  {'': '1889',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "They look good. Very individual, smart and cool… the sole is not too thick. But I'm going to get insoles for the inside. In terms of comfort, I think that depends on the shape of your foot…they hurt my heels a bit, but they're fine if you wear thicker socks. Otherwise they are hard to get on and off. ",
#   'Title': 'Overly expensive'},
#  {'': '1890',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'the top section is too tight and rubs',
#   'Title': 'Tight at the neck'},
#  {'': '1891',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'great shoes - suitable for any occasion',
#   'Title': 'very happy!'},
#  {'': '1892',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'fast delivery, great choice!',
#   'Title': 'Review'},
#  {'': '1893',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'Great quality and the best design by Boxfresh! After being really disappointed by the quality of Pointers, I have decided that Boxfresh are the shoe brand for me. Only drawback: they are really hot and sweaty… so really better for the winter (but not with the white sole!)',
#   'Title': 'Yes, they fit!'},
#  {'': '1894',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "I must say, everything went well - no problems - smart, comfortable, modern - I'm really happy!",
#   'Title': 'Fabulous shoes…'},
#  {'': '1895',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'Good shoes, but a bit expensive. The tongue is a bit too short for my liking.',
#   'Title': 'good but not cheap'},
#  {'': '1896',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'They are a bit uncomfortable',
#   'Title': 'Heels'},
#  {'': '1897',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'Very fast delivery, good quality, informative, good service and nice customer service staff ;)',
#   'Title': 'flawless'},
#  {'': '1898',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'I am very satisfied with these shoes. They fit as expected, look great and are very robust.',
#   'Title': 'Great shoes'},
#  {'': '1899',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'Great shoes, good delivery service. Good options for payment. Also great range.',
#   'Title': 'completely satisfied'},
#  {'': '1900',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "good colour combination, I would've liked better soles though!",
#   'Title': 'Very quick delivery'},
#  {'': '1901',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': '…really uncomfortable!',
#   'Title': 'Look great…'},
#  {'': '1902',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'very good shoes, but just a bit expensive',
#   'Title': 'leather trainers'},
#  {'': '1903',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'fast delivery, everything was great, fab product',
#   'Title': 'really nice shoes'},
#  {'': '1904',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'lovely shoes, unfortunately the soles are too soft and wear out very quickly',
#   'Title': 'Quite expensive'},
#  {'': '1905',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'Boxfresh…always great',
#   'Title': 'good shoes'},
#  {'': '1906',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': "I am very happy with the shoes and with Zalando's service",
#   'Title': 'To be recommended'},
#  {'': '1919',
#   'LanguageCode': 'en',
#   'SKU': 'BO2-m02-0008-03',
#   'Text': 'A quality Boxfresh casual shoe / trainer. Slightly larger fit. Thin & very uncomfortable sole. \r\n\r\nThe second day I wore these, I did a fair bit of walking and paid for it with some almighty blisters! I now have some inner soles in them and all is well again. So I would definately recommend buying some inner soles to fit these when purchasing.',
#   'Title': "Boxfresh 'Eavis' High-top trainers - brown"},
#  {'': '2581',
#   'LanguageCode': 'en',
#   'SKU': 'SK1-f25-0026-10',
#   'Text': 'Really pleased with the look and feel of this boot well worth the money! The only thing I would say against them is they are a large 7 so slightly looser than i thought but plenty of room to wear thick socks with them.',
#   'Title': 'a lovely comfy boot'},
#  {'': '2591',
#   'LanguageCode': 'en',
#   'SKU': 'SK1-f25-0026-10',
#   'Text': "These are lovely boots, very comfy (especially because you can adjust the width and leg fitting using the lace up front) and warm but not too warm.  I can't really comment on the quality because I've only had them a few days, but they seem well made.  However, they are huge!  I'm usually a 7.5 and have worn size 7 Skechers before, but I ended up with a size 6 in these boots as the 7s were so long I would have been tripping over them.",
#   'Title': 'lovely but big'},
#  {'': '2755',
#   'LanguageCode': 'en',
#   'SKU': 'SK1-fza-0268-99',
#   'Text': 'Great fit, fit like a glove - look great on as well',
#   'Title': 'Great sandals'},
#  {'': '2906',
#   'LanguageCode': 'en',
#   'SKU': 'AI2-m40-0010-03',
#   'Text': 'In my opinion Iso-Parcour make the best winter boots money can buy. The neoprene lining insulates the feet against extreme cold (-20!!!) You only need to wear thin stockings or socks - that way you feel as if you are walking barefoot through the snow! Long walks in snow are no problem with these boots. Two small criticisms: the price is really steep and you can really only wear these boots in minus temps. At +10 these boots are far too heavy and hot.',
#   'Title': "The best boots for winter I've found"},
#  {'': '3548',
#   'LanguageCode': 'en',
#   'SKU': 'LO2-m01-0008-01',
#   'Text': 'I ordered the shoes in my size and they seem a lot bigger!!!!',
#   'Title': 'Size'},
#  {'': '3549',
#   'LanguageCode': 'en',
#   'SKU': 'LO2-m01-0008-01',
#   'Text': 'A very high quality shoe',
#   'Title': 'Review'},
#  {'': '3550',
#   'LanguageCode': 'en',
#   'SKU': 'LO2-m01-0008-01',
#   'Text': 'The shoes look just like the pictures on the online shop, which I was very happy about!! My size fit perfectly and after a few days of wearing them in they were very comfortable. The only thing that is a shame is that the shoes are "Made in India", despite being marketed as a traditional English brand. For this price, I would expect better.',
#   'Title': 'Exactly what I ex'},
#  {'': '5838',
#   'LanguageCode': 'en',
#   'SKU': 'DI1-fzw-0108-99',
#   'Text': "I saw a lot of positive reviews about these so I got myself a pair and I'm impressed. Really trendy and comfy",
#   'Title': 'Splendid shoes'},
#  {'': '6016',
#   'LanguageCode': 'en',
#   'SKU': 'GU1-bzw-0036-99',
#   'Text': 'Love this handbag its slighter bigger than i thought but will do wonderfully!  Wish Guess did a smaller version with single handle and more options in this mixed colours!!',
#   'Title': 'Alina Handbag'},
#  {'': '6327',
#   'LanguageCode': 'en',
#   'SKU': 'TO211L000-K11',
#   'Text': 'Excellent!',
#   'Title': 'Very good quality'},
#  {'': '6671',
#   'LanguageCode': 'en',
#   'SKU': 'TO1-xzw-0216-99',
#   'Text': 'fantastic, as usual from TH',
#   'Title': '…'},
#  {'': '7173',
#   'LanguageCode': 'en',
#   'SKU': 'PU154J004-802',
#   'Text': "i'm really happy with this product, perfect!",
#   'Title': 'perfect!'},
#  {'': '7541',
#   'LanguageCode': 'en',
#   'SKU': 'DO2-fzw-0034-99',
#   'Text': 'Fab boots for winter. Warm fur lined right to the toes and very comfy. Was worried about fake websites but these are genuine and were delivered promptly.',
#   'Title': 'Dr Martin'},
#  {'': '8544',
#   'LanguageCode': 'en',
#   'SKU': 'VE121B020-503',
#   'Text': 'Very fast delivery and really cool pants',
#   'Title': 'Great!'},
#  {'': '9033',
#   'LanguageCode': 'en',
#   'SKU': 'RI111D012-505',
#   'Text': "this sandles are fantasic like walking on air they are so light you don't know you have them on.  I will buy lots more pairs for the future.",
#   'Title': 'comfort'},
#  {'': '9379',
#   'LanguageCode': 'en',
#   'SKU': 'MI323I002-002',
#   'Text': 'fits well',
#   'Title': 'honey'},
#  {'': '9549',
#   'LanguageCode': 'en',
#   'SKU': 'SK511A002-917',
#   'Text': 'I am a UK size 6 (EU 39) and these shoes fit me perfectly. extra comfort is added by having a proper insole. I have been wearing these shoes for shopping, sightseeing and general summer activites, which all involve a lot of walking and I havnt had any problems at all. very comfortable shoes with a cool look!!',
#   'Title': 'great summer shoes!!'},
#  {'': '9793',
#   'LanguageCode': 'en',
#   'SKU': 'PU112Z001-702',
#   'Text': 'good looking trainers',
#   'Title': 'great shoes'},
#  {'': '10223',
#   'LanguageCode': 'en',
#   'SKU': 'BU112E004-704',
#   'Text': 'nice shoes, good fit. need wearing in a bit at first though',
#   'Title': 'bugatti cash'},
#  {'': '10237',
#   'LanguageCode': 'en',
#   'SKU': 'VE121F017-503',
#   'Text': 'Lovely cotton, tight fit, nice length, great quality and colour.',
#   'Title': 'Great Long sleeve Top'},
#  {'': '10434',
#   'LanguageCode': 'en',
#   'SKU': 'AN611D00N-501',
#   'Text': 'So very comfortable and looks beautiful',
#   'Title': 'Grey Thongs'},
#  {'': '10913',
#   'LanguageCode': 'en',
#   'SKU': 'FL211Z00D-702',
#   'Text': 'So excited about wearing this comfortable, great looking, all round sandal this year. The colour purple is muted and therefore perfect with a number of outfits. The leather and laces are soft and comfortable. A great shoe/sandal.',
#   'Title': 'Fly YLVA purple sandal'},
#  {'': '11134',
#   'LanguageCode': 'en',
#   'SKU': 'RU321B008-704',
#   'Text': 'Really unusual shape - tight enough but more comfortable than skinnies - waste a little big but good loops for belt - a good look altogther',
#   'Title': 'haiti pants'},
#  {'': '11306',
#   'LanguageCode': 'en',
#   'SKU': 'SE622B006-953',
#   'Text': 'looks good but very small and tight',
#   'Title': 'looks good but very small and tight'},
#  {'': '11369',
#   'LanguageCode': 'en',
#   'SKU': 'B2042A005-702',
#   'Text': 'I would recommend ordering them one size larger than usual, but otherwise ok',
#   'Title': 'Cool slippers'},
#  {'': '11475',
#   'LanguageCode': 'en',
#   'SKU': 'JA222B00N-704',
#   'Text': 'They look lighter in the pictures than they really are',
#   'Title': 'Colour'},
#  {'': '11931',
#   'LanguageCode': 'en',
#   'SKU': 'TA111Z00L-802',
#   'Text': 'nice sandals comfortable fit. Would recommend to a friend!',
#   'Title': 'nice sandals!'},
#  {'': '12356',
#   'LanguageCode': 'en',
#   'SKU': 'DK211B006-802',
#   'Text': 'these shoes are stylist and look good with dresses or trousers , lovely',
#   'Title': 'black swan'},
#  {'': '12727',
#   'LanguageCode': 'en',
#   'SKU': 'AD113C00G-502',
#   'Text': 'Great product packed very well fast delivery',
#   'Title': 'brilliant'},
#  {'': '12909',
#   'LanguageCode': 'en',
#   'SKU': 'NI554A001-302',
#   'Text': 'bag big enough to hold football in base and other items on top of it, along with outer pockets, can be made smaller with straps or lets you add extra by letting straps out, carries more than it looks like it will, fits well on back or over shoulder,',
#   'Title': 'great bag'},
#  {'': '12974',
#   'LanguageCode': 'en',
#   'SKU': 'PE121B02D-952',
#   'Text': 'too small',
#   'Title': 'too small'},
#  {'': '12979',
#   'LanguageCode': 'en',
#   'SKU': 'AD554A002-002',
#   'Text': 'Item is as expacted,good size,and quality',
#   'Title': 'nice original retro bag'},
#  {'': '13384',
#   'LanguageCode': 'en',
#   'SKU': 'SE911D00N-202',
#   'Text': 'This product is really beautiful,it suit my dress.',
#   'Title': 'My yellow shoe.'},
#  {'': '13405',
#   'LanguageCode': 'en',
#   'SKU': 'TO211C006-102',
#   'Text': 'comfy shoe looks good and the heel is just right.',
#   'Title': 'satisfied customer'},
#  {'': '13600',
#   'LanguageCode': 'en',
#   'SKU': 'RI111C009-802',
#   'Text': "Managed to get these in the sale and I'm over the moon with them. I am normally a  size 7 so ordered a 7.5 glad I did as I got size 41 which fit perfectly. The quality is good and there really comfortable..\r\nHighly recommended",
#   'Title': 'A lovely boot'},
#  {'': '13786',
#   'LanguageCode': 'en',
#   'SKU': 'VE121F04N-802',
#   'Text': 'for XL far far too small',
#   'Title': 'wish I was this small'},
#  {'': '13817',
#   'LanguageCode': 'en',
#   'SKU': 'BU112X00M-702',
#   'Text': 'This is one of my alltime best buys todate,the stars speak for what I think about this product.I just love it.',
#   'Title': 'Quality Trainers'},
#  {'': '13827',
#   'LanguageCode': 'en',
#   'SKU': 'EL822X004-703',
#   'Text': 'There is no minuses for this product. This jacket is light and worm.  Looks and fits very well. You cannot expect more. Element was always good.',
#   'Title': 'This is great jacket'},
#  {'': '14033',
#   'LanguageCode': 'en',
#   'SKU': 'CA512A007-702',
#   'Text': 'too big',
#   'Title': 'too big'},
#  {'': '14323',
#   'LanguageCode': 'en',
#   'SKU': 'PA311X005-708',
#   'Text': 'everything i wanted in a boot i have been trying to buy these boots for ages lovely quality many thanks',
#   'Title': 'panama jack Caryn boots'},
#  {'': '14367',
#   'LanguageCode': 'en',
#   'SKU': 'M5611X004-205',
#   'Text': 'Because shoe is new it is a little tight at the toes and insole area',
#   'Title': 'Right Size'},
#  {'': '14616',
#   'LanguageCode': 'en',
#   'SKU': 'MU311C01J-102',
#   'Text': 'Boots are a bit cheap looking, they are slightly too narrow across the toes for me but I have wide feet\r\nThe laces are much longer than needed\r\nNice heel height & good enough to keep them',
#   'Title': 'Grey boot'},
#  {'': '15056',
#   'LanguageCode': 'en',
#   'SKU': 'ME421G007-503',
#   'Text': 'Wow, this coat does turn heads!  Yes, it is pricey but it worth every penny as they say.  It is very warm, soft to touch and looks fabulous with a lurex hat etc.  It has that S.. and The City feel especially with a nice pair of high heel boots.',
#   'Title': 'Luxurious Coat'},
#  {'': '15132',
#   'LanguageCode': 'en',
#   'SKU': 'MJ111C00Y-708',
#   'Text': 'they are so lovely and fashionable! And so so comfortable! But a little to expensive, but their look compensate me that:)',
#   'Title': 'Fab'},
#  {'': '15721',
#   'LanguageCode': 'en',
#   'SKU': 'HA541A00E-102',
#   'Text': "I bought these as I have really wide feet and already own a pair of Hanwag hiking boots which have given me years of comfortable service. I found the shoes slightly tighter than my boots, which are the same size and took the precaution of wearing them in for a couple of days round the house before going for a walk in them and had no problems. Ideally, the laces could be a couple of centimetres longer but  they are very well made, comfortable, with an excellent grippy sole and I'm sure will last me years.",
#   'Title': 'Performance XCR shoes'},
#  {'': '15802',
#   'LanguageCode': 'en',
#   'SKU': 'AI216C008-503',
#   'Text': "Finally a good, plain pair of wellies for cool kids - that aren't cutsey. These are perfect for school trips/excursions to the country for the fashion-conscious kids of today. These wellies are fab, but the rubber stinks at first - just but them outside on the porch for a few days to air them out.",
#   'Title': 'Cool wellies with warm lining'},
#  {'': '15873',
#   'LanguageCode': 'en',
#   'SKU': 'PE122A00R-905',
#   'Text': 'Smart jeans',
#   'Title': 'Great'},
#  {'': '15915',
#   'LanguageCode': 'en',
#   'SKU': 'TO121X01Y-704',
#   'Text': 'I ordered the cardigan in a size XL (because I know that TH sometimes cuts really small) .... when it arrived I was shocked and everyone I showed the cardi with me - might as well was a size S ... max M BUT DEF NOT XL',
#   'Title': "correct fit: large - I don't think so"},
#  {'': '16013',
#   'LanguageCode': 'en',
#   'SKU': 'WR111C002-704',
#   'Text': 'this was exactly what I was looking for.  My wife was very pleased.  Thanks for the selection and the quick delivery',
#   'Title': 'Mr'},
#  {'': '16062',
#   'LanguageCode': 'en',
#   'SKU': 'B1111C00R-802',
#   'Text': 'Comfortable and stylish.  Not an UGG but hey, half the price.',
#   'Title': 'Better than expected'},
#  {'': '16170',
#   'LanguageCode': 'en',
#   'SKU': 'MI321X008-605',
#   'Text': 'Fantastic winter coat!',
#   'Title': 'Perfect'},
#  {'': '16484',
#   'LanguageCode': 'en',
#   'SKU': 'AN621I01G-902',
#   'Text': 'Verey nice put I should take smaller than my size',
#   'Title': 'Nice'},
#  {'': '16523',
#   'LanguageCode': 'en',
#   'SKU': 'NI144A01I-002',
#   'Text': 'ok',
#   'Title': "yes,it's ok"},
#  {'': '16659',
#   'LanguageCode': 'en',
#   'SKU': 'EM111C008-707',
#   'Text': 'boots arrived 6 days after ordering which was fine - very excited to get my new boots for my xmas present only to find that they had sent me the wrong style and the wrong size !!! no xmas present for me to open on xmas day  :(\r\nvery disappointed, on the positive side -  great quality boots',
#   'Title': 'wrong order'},
#  {'': '16730',
#   'LanguageCode': 'en',
#   'SKU': 'PI911Y00K-O11',
#   'Text': "They looked so nice but I couldn't even get them on so unfortunately they are going straight back :-(",
#   'Title': 'Too small'},
#  {'': '16841',
#   'LanguageCode': 'en',
#   'SKU': 'JE711C007-702',
#   'Text': 'i luv this shoe so much not only because it is nice but very comfortable. i can even wear it to go shopping all day!!',
#   'Title': 'best shoe ever!!'},
#  {'': '17244',
#   'LanguageCode': 'en',
#   'SKU': 'SA312A006-708',
#   'Text': 'I was on the look out for some redwing boots and was a bit put off by the costs, then, I came across these. For £80 these are comfortable, well made and considerably cheaper.',
#   'Title': 'Affordable boots that boast sttle'},
#  {'': '17668',
#   'LanguageCode': 'en',
#   'SKU': 'CO422D001-802',
#   'Text': 'Medium size was larger than with some other brands but that was OK for me as have bought Converse before so knew this.\r\n\r\nOverall very pleased with quality of product and delivery service from Zalando',
#   'Title': 'Converse T Shirt'},
#  {'': '17780',
#   'LanguageCode': 'en',
#   'SKU': 'GS154D002-703',
#   'Text': 'Smart, stylish and ideal for causual wear',
#   'Title': 'New Rhames Belt Brown'},
#  {'': '17829',
#   'LanguageCode': 'en',
#   'SKU': 'AR211A00C-707',
#   'Text': 'These shoes are hard  to get into - smaller and narrower than a true size. I ordered one whole size larger in the hope that the "Porno" pointy shoes might look halfway decent. But I was fooling myself. These shoes are not at all trendy they look cheap. Th',
#   'Title': 'Tight squeeze'},
#  {'': '17844',
#   'LanguageCode': 'en',
#   'SKU': 'ZA521G002-112',
#   'Text': "This doesn't really fit at all in any good way!",
#   'Title': 'Just bad'},
#  {'': '18030',
#   'LanguageCode': 'en',
#   'SKU': 'F1311C00R-802',
#   'Text': 'These boots are black and not brown. I sent them back. How annoying.',
#   'Title': 'Wrong colour'},
#  {'': '18207',
#   'LanguageCode': 'en',
#   'SKU': 'AE751E00O-D11',
#   'Text': 'very nice ring !',
#   'Title': 'NICE ONE '},
#  {'': '18493',
#   'LanguageCode': 'en',
#   'SKU': 'GI111D009-002',
#   'Text': "Really pleased with these slippers.  They are really warm while letting your feet breathe.  The latex sole gives good grip and the shape of the slipper covers quite alot of the foot.  There isn't much support with these slippers so if your looking to wear them as a day shoe for working in the house these probably aren't for you but as slippers for relaxing, these are great!",
#   'Title': 'Little bit of luxury!'},
#  {'': '18515',
#   'LanguageCode': 'en',
#   'SKU': 'MI511A00N-002',
#   'Text': 'Oh my goodness these are the best shoes in the whole wide world! \r\nThere so beautiful!',
#   'Title': 'Prettiest shoes in the world!'},
#  {'': '18930',
#   'LanguageCode': 'en',
#   'SKU': 'LE221A008-902',
#   'Text': "I'm quite tall so I find it difficult to find high waisted jeans that fit properly and are actually high waisted, but these were, they're really great and they won't wear out quickly so they're worth the money.",
#   'Title': 'Really good'},
#  {'': '18937',
#   'LanguageCode': 'en',
#   'SKU': 'RI213A00F-302',
#   'Text': 'As always Ricosta has come up trumps!  Trying to find well-made shoes with an excellent fit has become quite a mission; however, my daughter loves these, they are comfy and even have in insole that can be taken out and washed.  Highly recommended!',
#   'Title': 'Lovely shoes by Ricosta'},
#  {'': '19006',
#   'LanguageCode': 'en',
#   'SKU': 'NE211S02J-K11',
#   'Text': 'So comfy, very good trainers ',
#   'Title': 'Brilliant '},
#  {'': '19233',
#   'LanguageCode': 'en',
#   'SKU': 'P2021K024-701',
#   'Text': 'Briefs are extremely comfortable  and sexy to wear. They cling lightly and are blissfully tactile.  A most enjoyable experience.',
#   'Title': 'smooth and sexy.'},
#  {'': '19247',
#   'LanguageCode': 'en',
#   'SKU': 'V1021C02G-602',
#   'Text': 'This is a lovely dress, it fits really well and looks great.',
#   'Title': 'Lovely dress'},
#  {'': '19430',
#   'LanguageCode': 'en',
#   'SKU': 'PE211A00E-917',
#   'Text': 'this is my second pair of this style - they are so easy to wear with everything, and the floral, multicoloured design is a great way of adding a bit of colour to your wardrobe. I take a size 5 1/2, but ordered in size 6, as my feet are fairly broad, and this is a very pointed style. The slingback,with extra piece at heel, always stays put. All in all a great buy.',
#   'Title': 'On trend & comfort too!'},
#  {'': '19515',
#   'LanguageCode': 'en',
#   'SKU': 'PE211A01H-704',
#   'Text': 'The shoe is stylish up to date with the neutral colour, a little disappointed with the quality of the finish - the patent appears wringled in a number of places. For the price I would expect it to be perfect.  Cannot fault the look and comfort - excellent.',
#   'Title': 'Classy'},
#  {'': '19731',
#   'LanguageCode': 'en',
#   'SKU': 'E1871C003-355',
#   'Text': 'After looking for a new esprit duvet cover for a while, I was pleased when I came across this on Zalando. Amazing quality for the price.  Colours did not run when being washed in the washing machine, and the material also feels nice against the skin.\r\nA great purchase that I would definitely recommend.',
#   'Title': 'Beautiful, good value'},
#  {'': '19748',
#   'LanguageCode': 'en',
#   'SKU': 'CO554D009-102',
#   'Text': 'Hello                                                                                                                                             \r\nI wish to buy this product.',
#   'Title': 'choice'},
#  {'': '20193',
#   'LanguageCode': 'en',
#   'SKU': 'BU211C033-704',
#   'Text': 'Excellent service and excellent product to match....I am more than pleased with the boots and the service. I will definitely used Zalando again.',
#   'Title': 'Excellent'},
#  {'': '20215',
#   'LanguageCode': 'en',
#   'SKU': 'JA222D06M-503',
#   'Text': 'Lovely looking t-shirt (vintage), really soft and good quality material (thicker than your average t-shirt). Very impressed, and will be purchasing another for a different family member. Good price too!',
#   'Title': 'Really good quality'},
#  {'': '20287',
#   'LanguageCode': 'en',
#   'SKU': 'N1242A030-802',
#   'Text': '?? reply asap',
#   'Title': 'can i wear this casually ?? on jeans'},
#  {'': '20713',
#   'LanguageCode': 'en',
#   'SKU': 'MI422G00G-502',
#   'Text': 'The jacket was very tight fitting,the quality of the material was very poor,I buy Paul Smith cloths and Ted Baker I will not be purchaseing any of these products in the future.',
#   'Title': 'Poor Quality'},
#  {'': '20720',
#   'LanguageCode': 'en',
#   'SKU': '4JO21H001-513',
#   'Text': 'Smart and warm coat for colder days - what more can one want?  Good length - mid thigh level, which covers you know what and yet is short enough to allow you to (try) to beat the kids at tag, cycling etc.',
#   'Title': 'Nice winter coat'},
#  {'': '20871',
#   'LanguageCode': 'en',
#   'SKU': '4BE22D001-002',
#   'Text': 'This top looks really great with my chinos and boots, I fasten the top button for that preppy on trend look , and it looks great, its very different to other high street polo shirts it fits great and is ever so slightly looser I love it , plan to get a few more colours , great quality and worth very penny , you can really tell the difference with Benetton clothes reallly well made and worth the money ! And thanks zalando for bringing the menswear to the UK online as its available nowhere else !!! Bonus !',
#   'Title': 'Cool..'},
#  {'': '21081',
#   'LanguageCode': 'en',
#   'SKU': 'NI251A011-305',
#   'Text': 'its not red ... Its orange',
#   'Title': 'Colour'},
#  {'': '21243',
#   'LanguageCode': 'en',
#   'SKU': '4JO21D00A-917',
#   'Text': 'loved actual top but a few concerns -no labels attached to item so unsure as to it s origin was it a return /or a second ?\r\n                                                                -over use of packaging to send one small cotton top -in a plastic bag surrounded by inflated plastic bags in an oversized cardboard box seemed a bit over protective and hardly necessary !',
#   'Title': 'Kristina -Joules blouse'},
#  {'': '21269',
#   'LanguageCode': 'en',
#   'SKU': 'AD542A05X-802',
#   'Text': 'This shoe is epic it is so comfortable and is a hot basketball shoe',
#   'Title': 'AMAZING'},
#  {'': '21411',
#   'LanguageCode': 'en',
#   'SKU': 'ME411B00A-204',
#   'Text': 'Like these a lot. Good foot support. Very stylish. Good colour. Under stated.',
#   'Title': 'Mexx Babara 3'},
#  {'': '21505',
#   'LanguageCode': 'en',
#   'SKU': 'N1241A0CR-K11',
#   'Text': 'Trainers are great, really comfortable, lovely colour. Recommend!!!',
#   'Title': 'Very happy!!!'},
#  {'': '22172',
#   'LanguageCode': 'en',
#   'SKU': 'BJ212C00G-102',
#   'Text': 'Shoes would have been great if the right size was sent.\r\nI ordered size 7, size 6 arrived. I spoke to telesales they told me to order size 42 european. I did and these were size too big. As the order had taken 2 weeks by this point, and I needed the shoes for a reason I ended up with a size too small which i shall never be able to use again, and very sore feet!',
#   'Title': 'Wrong sizes'},
#  {'': '22287',
#   'LanguageCode': 'en',
#   'SKU': 'MO421D013-002',
#   'Text': "I prefer longer line tops so was really excited to receive this one. The fabric is really soft and the detailing is cute. The price is expensive but finding the right sort of tops, with good fabric is difficult. I bought XS and am UK size 6-8 and it was HUGE. I could have adjusted the side seams to take it in from the bust downwards but really, if I'm spending that much, I shouldn't have to. Returned it. I really think Zalando need to add more info on sizing for individual items.",
#   'Title': 'lovely top but way too big'},
#  {'': '22365',
#   'LanguageCode': 'en',
#   'SKU': 'SO422D029-503',
#   'Text': 'very nice.I like',
#   'Title': 'Long Sleeve Top'},
#  {'': '22568',
#   'LanguageCode': 'en',
#   'SKU': 'LA212A02H-502',
#   'Text': 'well designed and smooth fit....whao',
#   'Title': 'art steps'},
#  {'': '22631',
#   'LanguageCode': 'en',
#   'SKU': 'AD542A1FL-C11',
#   'Text': 'still waiting for return label so i can return a pair of running shoes, because they were to small. it said 6 days but still waiting.could you tell me how long will i be waiting???',
#   'Title': 'returns'},
#  {'': '23685',
#   'LanguageCode': 'en',
#   'SKU': 'VA651D01K-802',
#   'Text': 'The belt is nice\r\nBut not for your usual jeans belt holes as its too narrow\r\nI think full specifications should appear at point of selection of this product',
#   'Title': 'Complete Specification'},
#  {'': '23953',
#   'LanguageCode': 'en',
#   'SKU': 'TH341B058-102',
#   'Text': 'Great fit, good price, swift delivery. Would recommend this for any travel.',
#   'Title': 'North Face Boulder Blouse'},
#  {'': '24486',
#   'LanguageCode': 'en',
#   'SKU': 'TI315A00V-702',
#   'Text': 'Really stylish, simple design. Excellent service from Zalando.co.uk',
#   'Title': 'Onitsuka Tiger Alty'},
#  {'': '24500',
#   'LanguageCode': 'en',
#   'SKU': 'NI111A02Y-304',
#   'Text': "When I looked at the photo I wasnt sure whether they would come out to be that colour or not, but they did. The reason I questioned this was the fact that they are called red, but they look more of a purple colour to me. They came in just under a week, I ordered them on a Sunday and they arrived the following saturday. Because I wasn't in they gave them to my neighbour, which was helpful. Overall I am pretty happy with the service and the trainers are great, really light and comfy.",
#   'Title': 'Red? I would call the colour more of a purple.'},
#  {'': '24717',
#   'LanguageCode': 'en',
#   'SKU': 'V1771B005-404',
#   'Text': 'soft to touch, and they dry you perfectly well. I recommend that people should try this type of a towel.',
#   'Title': 'Vossen Towel'},
#  {'': '24928',
#   'LanguageCode': 'en',
#   'SKU': 'HU822D012-812',
#   'Text': 'Poor quality material, faulty logo and would not use this company again as all three products purchased were faulty.',
#   'Title': 'Disappointing'},
#  {'': '25088',
#   'LanguageCode': 'en',
#   'SKU': 'ZI111A03E-051',
#   'Text': 'Shoes are excellent Im so satisfy, many thanks',
#   'Title': 'dorra'},
#  {'': '25136',
#   'LanguageCode': 'en',
#   'SKU': 'EV211A00Y-708',
#   'Text': 'I want to buy this shoes, my size is 3.5.Canyou help me check .',
#   'Title': 'Like'},
#  {'': '25828',
#   'LanguageCode': 'en',
#   'SKU': 'S3722G00X-909',
#   'Text': 'Good quality, nice fit.',
#   'Title': 'Lovely'},
#  {'': '25970',
#   'LanguageCode': 'en',
#   'SKU': 'WR121A014-954',
#   'Text': 'These wrangler jeans are true to size, nice cut and colour - the only disappointing aspect of the design is the pockets are not very deep and not much contrasting stitching, so they are rather plain , but overall a great pair of jeans for the wardrobe.',
#   'Title': 'Classic jean'},
#  {'': '26019',
#   'LanguageCode': 'en',
#   'SKU': 'JE311A00K-304',
#   'Text': 'Bought these shoes to wear with skinny jeans. I had to buy a larger size because my normal size was too tight at the toes, but the larger size fits well and I like them a lot.',
#   'Title': 'Sizing quite small but a lovely shoe'},
#  {'': '26057',
#   'LanguageCode': 'en',
#   'SKU': 'BM134B00S-918',
#   'Text': 'Overall good product. The cream is very rich and the smell is nice although a bit overpowering for the first few minutes. The cream feels a bit sticky but once it penetrates the skin my hands are well moisturised.',
#   'Title': 'Good product'},
#  {'': '26159',
#   'LanguageCode': 'en',
#   'SKU': 'S7411B006-414',
#   'Text': "Discovered these Oz-made 'Souls' Flip Flops in New Zealand in 2008 - brilliant! but sadly lost a pair on a beach in Bali!  So, VERY happy to rediscover that Zalando sells them!\r\nWould definitely recommend them.",
#   'Title': 'Recommend'},
#  {'': '26219',
#   'LanguageCode': 'en',
#   'SKU': 'SA321I018-113',
#   'Text': "This is a lovely quality jumper. It's a relaxed fit but not too big, a lovely shape and the neckline is not too high up. A great piece for those cold winter days, which goes with everything... scarves, short skirts or jeans.",
#   'Title': 'Lovely Jumper'},
#  {'': '26555',
#   'LanguageCode': 'en',
#   'SKU': 'AN611C050-103',
#   'Text': 'These boots are good quality, a good fit,  and are very comfortable.  However the ankles are baggy giving your leg a tree trunk appearance.  Heel not too high so good for work.',
#   'Title': 'Beautiful but has baggy ankles'},
#  {'': '26930',
#   'LanguageCode': 'en',
#   'SKU': 'MJ111C02A-708',
#   'Text': 'Absolutely gorgeous, beautiful colour and high quality leather. Cannot waith until autumn or winter as warm lining inside.',
#   'Title': 'Fabulous!'},
#  {'': '27146',
#   'LanguageCode': 'en',
#   'SKU': 'AD542A1XX-K11',
#   'Text': 'Perfect!',
#   'Title': 'Perfect'},
#  {'': '27217',
#   'LanguageCode': 'en',
#   'SKU': 'AN651GA0C-Q11',
#   'Text': 'Beautiful, ordered two more different colours ',
#   'Title': 'Happy'},
#  {'': '27562',
#   'LanguageCode': 'en',
#   'SKU': 'KH122G01D-802',
#   'Text': 'Great service by Zalando, this is my first Khujo jacket and it really is a quality jacket. So much detail has been put into this. It is very warm and fits really well. The hood is detachable so I can wear other hooded tops with this. A great winter jacket that has style and warmth. I love my new jacket thanks.',
#   'Title': 'Excellent quality'},
#  {'': '27975',
#   'LanguageCode': 'en',
#   'SKU': 'SO511C00A-304',
#   'Text': 'The best pair of ankle boots I have ever had.  Fitted perfectly around my ankle (always find other boots too loose here) absolutely love them, just wish I had been quick enough to get them in black too...alas,  my size is no longer available.  Does anyone have a size 5 in black they want to sell???????',
#   'Title': 'Ab Fab'},
#  {'': '28048',
#   'LanguageCode': 'en',
#   'SKU': 'HE641B00M-502',
#   'Text': 'This is £90 in Blacks.',
#   'Title': 'Over priced on here'},
#  {'': '28334',
#   'LanguageCode': 'en',
#   'SKU': 'AN621I029-404',
#   'Text': "The colour looks like it does in the photos (not always the case when buying online) and the fit is good.  Haven't washed it yet so not sire how it'll fare in the machine but so far so good.",
#   'Title': 'Just like the pictures'},
#  {'': '28456',
#   'LanguageCode': 'en',
#   'SKU': 'ZI111C09L-603',
#   'Text': "This is a great boot and good quality for the price. It seems that they would last a long time. I didn't give them 5 stars for comfort and had to return them more for personal reasons: I have club feet and therefore have very thin ankles - the ankle area of the boot was too big on me and soft so it provided no support. They were also just a little too high, pushing my toes forward. On the design frontI gave them 4 stars as they are a very dark green, almost black and I would have preferred a more vibrant green. As I have said though, these are all personal problems and for someone else they would be lovely!",
#   'Title': 'Just a little too high for me.'},
#  {'': '28606',
#   'LanguageCode': 'en',
#   'SKU': 'ON543B01W-355',
#   'Text': 'I was not very impressed by its quality for its price.  I would not say it does not meet the quality for the value.',
#   'Title': 'not quality for its value'},
#  {'': '28800',
#   'LanguageCode': 'en',
#   'SKU': 'MO312C019-802',
#   'Text': 'I love the style of these boots with their distressed finish giving the impression someone has already worn them in for you! They give the impression of being smart and casual at the same time so work with whatever you wear. I feel they are going to have a long and happy relationship with my feet :)',
#   'Title': 'Charlie Chaplin Boots'},
#  {'': '28859',
#   'LanguageCode': 'en',
#   'SKU': 'FL211C014-802',
#   'Text': 'These boots are FABULOUS - beautifully styled and extremely comfortable to wear.  They are a great length - fitting almost on the knee. I trust this brand time and time again - well worth the extra money - and they are built to last! Great GREEN colour - not too bright and look fab in daylight and more of a smokey black in the evening. RECOMMEND to all Fly London fans.',
#   'Title': 'Best yet FLY LONDON boots!!!!'},
#  {'': '29141',
#   'LanguageCode': 'en',
#   'SKU': 'M3111C040-802',
#   'Text': 'Fab boot and excellent service, thank you',
#   'Title': 'Boots'},
#  {'': '29159',
#   'LanguageCode': 'en',
#   'SKU': 'TA911A01P-602',
#   'Text': "A nice choice,different makes I'm very happy.",
#   'Title': 'Mimi'},
#  {'': '29162',
#   'LanguageCode': 'en',
#   'SKU': 'BI752E011-503',
#   'Text': 'please with the item.',
#   'Title': 'good product'},
#  {'': '29262',
#   'LanguageCode': 'en',
#   'SKU': 'B2321K00Z-302',
#   'Text': 'lives upto its name. the only thing to be aware of, they are more like a pant than shorts. Saying that, they are very stylish and comfortable',
#   'Title': 'lovely underwear'},
#  {'': '29480',
#   'LanguageCode': 'en',
#   'SKU': 'AD542B115-302',
#   'Text': "Not impressed - no attempt was ever made to deliver, then i got a refund out oif the blue. My advice would be; don't bother ordering from this company!",
#   'Title': 'Item failed to arrive.... then I was given a refund - all I wanted was the goods!'},
#  {'': '30052',
#   'LanguageCode': 'en',
#   'SKU': 'AS141A03S-002',
#   'Text': 'THE TENNIS SHOE IS GREAT, ARRIVED PROMPTLY,VERY COMFORTABLE AND THEY LOOK GOOD.HAVE RECOMMENDED  THEM TO MY FRIENDS AT THE TENNIS CLUB.',
#   'Title': 'ASICS INDOOR CARPET SHOE'},
#  {'': '30357',
#   'LanguageCode': 'en',
#   'SKU': 'L3344A00A-802',
#   'Text': "They are amazing! Came in a parcel properly packed and secured, on time and been walking with them since. They are very comfortable and I'm very very happy with them.",
#   'Title': 'Leki SoftLlite AS walking poles'},
#  {'': '30575',
#   'LanguageCode': 'en',
#   'SKU': 'J1822J008-502',
#   'Text': 'ordered a large  took 8 days get here...very small and i thouhgt it would be thicker..am sending back....disapointed....',
#   'Title': 'OVERPRICED'},
#  {'': '30589',
#   'LanguageCode': 'en',
#   'SKU': 'TA111A08S-802',
#   'Text': 'Excellent shoe  good fit very comfortable',
#   'Title': 'Fabulous Shoe'},
#  {'': '30764',
#   'LanguageCode': 'en',
#   'SKU': 'PW222I004-604',
#   'Text': 'Delivered as promised ..service is excellent from the company .....The Item is as described nice color, quality Jumper for cold winters ...All in all I give 5/5',
#   'Title': 'Peter Werth GARDNER - Jumper - olive Color'},
#  {'': '31178',
#   'LanguageCode': 'en',
#   'SKU': 'KO121I02T-802',
#   'Text': 'I really liked this jumper and its shimmering colours, unfortunately i ordered the smallest size and felt that it was too big so had to return it.  If it came in a smaller size i would definately re order it!',
#   'Title': 'Stunning Jumper'},
#  {'': '32376',
#   'LanguageCode': 'en',
#   'SKU': 'HI122F030-502',
#   'Text': 'Stunning shirt, great detail, excellent value',
#   'Title': 'Stunning'},
#  {'': '32466',
#   'LanguageCode': 'en',
#   'SKU': 'J3523G005-503',
#   'Text': 'FABULOUS COAT - A REAL EYE CATCHER.....MY DAUGHTER (age 5) had had so many compliments since purchasing this...........beautiful quality & true to size',
#   'Title': 'jOTTUM - DOES IT AGAIN'},
#  {'': '32815',
#   'LanguageCode': 'en',
#   'SKU': 'TE422I004-903',
#   'Text': "Zealand's was the only shopping site with Ted \r\nBaker stock in range of sizes just before Christmas, so great choice and delivery quick and cheaper than other sites,",
#   'Title': 'Review'},
#  {'': '32979',
#   'LanguageCode': 'en',
#   'SKU': 'KW311C009-702',
#   'Text': "I have long wanted a pair of cowboy boots but been reluctant to purchase without trying them on.  Saw these and couldn't resist so awaited them with much trepidation but they are PERFECT!  Well made and superb quality.  I did order a half size larger as I have a wide foot and wanted to wear them with socks but I think the sizing is good generally.  I am absolutely thrilled with my boots and would recommend this make.",
#   'Title': 'FABULOUS BOOTS'},
#  {'': '33186',
#   'LanguageCode': 'en',
#   'SKU': 'DC322A004-952',
#   'Text': 'The Tinnu cut manages to combine a really close fit around upper legs and butt with shall I say "room for manoeuvre" where the fly studs are. So it\'s really comfortable whatever the state of play. These jeans are just right for the man who enjoys his masculinity. Striding the street, or strutting the dance floor, he\'ll get second glances.',
#   'Title': 'Shapely Show'},
#  {'': '33206',
#   'LanguageCode': 'en',
#   'SKU': 'PA611B02H-702',
#   'Text': "I'm a real fan of Birkenstock. Can't take them off my feet.  The comfort is like nothing on earth. This particular one is very versatile, being a plain brown colour, but it still has a bit of pizazz with the inlaid pattern. Lovely.\r\n\r\nAlso, a bit about Zalando. Very impressed with their customer service. Needed to return a faulty item and they were very helpful. recommend the site",
#   'Title': 'Fantastic shoes'},
#  {'': '33407',
#   'LanguageCode': 'en',
#   'SKU': 'BU152D00F-802',
#   'Text': 'If you have trousers waist size 36 you will need a Bugatti belt size 40 at least',
#   'Title': 'Bugatti belts measure small!'},
#  {'': '33416',
#   'LanguageCode': 'en',
#   'SKU': 'BU152D00K-802',
#   'Text': 'Nice belt but too small so will have to return.  Seems to measure 2 inches smaller than advertised',
#   'Title': 'Size 36 is more like size 34!'},
#  {'': '33466',
#   'LanguageCode': 'en',
#   'SKU': 'JA222A04U-909',
#   'Text': 'More skinny than slim',
#   'Title': 'skinny'},
#  {'': '33941',
#   'LanguageCode': 'en',
#   'SKU': 'ZA522G003-909',
#   'Text': "I've been looking for a light jacket for quite a while and just could not find exactly what I wanted until I found this one. Based on what I could see and trusting in Zalando's knowledge of quality products and styling, I decided to purchase this jacket and I couldn't have made a better choice. The quality of the the jacket far outweighs other similar products at twice the price. The fit for me was perfect. I just liked everything about it!!",
#   'Title': 'A Jacket For All Seasons.'},
#  {'': '34064',
#   'LanguageCode': 'en',
#   'SKU': 'B5411C00B-802',
#   'Text': "These boots are lovely for the style/ leather but the finish was really bad on the silver trim at the front - the glue was visible and the silver was actually peeling off to a red/ brass type colour on one boot.  I sent them back.  I was really disappointed as I love the style of the boot but for £110 they should have a quality finish which they did not. The fit is also slightly small but I presume in wearing the leather would give a bit - just a shame I won't be wearing them in at all now :(",
#   'Title': 'Lovely boots bad finish'},
#  {'': '34226',
#   'LanguageCode': 'en',
#   'SKU': 'ZA511C01G-558',
#   'Text': 'Fabulous boots, great design and look neat on the foot dispite the wedge. Comfortable and trendy.',
#   'Title': 'Wedge boots'},
#  {'': '34290',
#   'LanguageCode': 'en',
#   'SKU': 'JA222I028-603',
#   'Text': 'Great jumper, good fit, good quality',
#   'Title': 'Great Jumper'},
#  {'': '34291',
#   'LanguageCode': 'en',
#   'SKU': 'JA222I028-504',
#   'Text': 'Great jumper, good fit, quality and value',
#   'Title': 'Great Jumper'},
#  {'': '34321',
#   'LanguageCode': 'en',
#   'SKU': 'M3941B01K-102',
#   'Text': 'I love this top good fit and style',
#   'Title': 'Comfortable top'},
#  {'': '34421',
#   'LanguageCode': 'en',
#   'SKU': 'K2851F01E-104',
#   'Text': 'These earrings are a fabulously large pair of statement earrings. I certainly won\'t be able to say to my husband, "What these old things, I\'ve had them for ages!!!" They are real head turners, super quality and design. I love the open metal work and the different sized diamante. Shopping with Zalando is such a pleasure. There is such a large choice of everything and the website is so easy to navigate and is so user friendly, I do regularly recommend my friends go online and see for themselves.',
#   'Title': 'Fabulous Konplott Silver & Diamante Earrings'},
#  {'': '35317',
#   'LanguageCode': 'en',
#   'SKU': 'ON321I045-111',
#   'Text': 'nice unusual cardigan,fits well ang feels cosy.',
#   'Title': 'winter warmer'},
#  {'': '36112',
#   'LanguageCode': 'en',
#   'SKU': 'AD111S07T-A11',
#   'Text': "These trainers are gorgeous and non-leather!!' They were initially too big because I'm a 4.5 and bought at 5 but the laces meant I could tighten them. I get so many compliments on these when I wear them. But I can't wear them if it's rainy because they're white as white!!",
#   'Title': 'Amazing '},
#  {'': '36923',
#   'LanguageCode': 'en',
#   'SKU': 'SO422I01D-502',
#   'Text': 'Very happy.\r\nLots of variety on website. Ordering easy. Quick delivery. Great!',
#   'Title': 'Happy customer...'},
#  {'': '37343',
#   'LanguageCode': 'en',
#   'SKU': 'LX151A001-302',
#   'Text': 'Bag was much smaller, not a large tote, and the handles were stiff and uncomfortable fer smallish hands-leather was quite thick',
#   'Title': 'Did not meet expectations'},
#  {'': '37533',
#   'LanguageCode': 'en',
#   'SKU': 'FU224A003-302',
#   'Text': 'Good quality and good service.',
#   'Title': 'Red jeans'},
#  {'': '37626',
#   'LanguageCode': 'en',
#   'SKU': 'TH342B0A1-603',
#   'Text': 'I am very pleased with my new t shirt!',
#   'Title': 'Mr'},
#  {'': '37737',
#   'LanguageCode': 'en',
#   'SKU': 'PO252B015-G11',
#   'Text': 'Great hat and lovely to wear..',
#   'Title': 'Cheep and RL is 100% well made.'},
#  {'': '37803',
# ...
#   'Title': 'best trainers ever '},
#  {'': '137402',
#   'LanguageCode': 'en',
#   'SKU': 'AD542A2C6-Q11',
#   'Text': 'Great buy',
#   'Title': 'Very comfortable &amp; look good.'},
#  {'': '137403',
#   'LanguageCode': 'en',
#   'SKU': 'A1822D05F-K11',
#   'Text': 'Nice fit, thin fabric though and one button coming off',
#   'Title': 'Disappointing'},
#  {'': '137570',
#   'LanguageCode': 'en',
#   'SKU': 'PQ411C000-Q11',
#   'Text': 'Shoes are really nice but size is not adequate. I bought 3 but it was like 5. Sadly I had to return them.',
#   'Title': 'Well made shoes, very good quality.'},
#  {'': '137615',
#   'LanguageCode': 'en',
#   'SKU': 'K4411IA0B-J11',
#   'Text': 'As you dont ship to Ireland you said you would have to cancel the order ',
#   'Title': 'vey dissapointed '},
#  {'': '137645',
#   'LanguageCode': 'en',
#   'SKU': 'ET981B04E-Q11',
#   'Text': 'The size is normal to fit, and the fabric is elastic with really pretty lace!',
#   'Title': 'Pretty and high-quality'},
#  {'': '137701',
#   'LanguageCode': 'en',
#   'SKU': 'AD543A1JX-K11',
#   'Text': 'Found product very small made ',
#   'Title': 'Too small need to return'},
#  {'': '137967',
#   'LanguageCode': 'en',
#   'SKU': 'UG112A00S-Q11',
#   'Text': 'Very nice boots',
#   'Title': 'Really comfortable '},
#  {'': '138019',
#   'LanguageCode': 'en',
#   'SKU': 'TI512C00S-K11',
#   'Text': 'satisfy ',
#   'Title': 'it look exactly the same product and my size.'},
#  {'': '138425',
#   'LanguageCode': 'en',
#   'SKU': 'TE411S00C-T11',
#   'Text': 'Beautiful design!',
#   'Title': 'Love the design and they are comfortable. Great for Spring time!'},
#  {'': '138431',
#   'LanguageCode': 'en',
#   'SKU': 'EA852M00L-Q11',
#   'Text': 'Unknown',
#   'Title': 'Wrong watch was sent'},
#  {'': '138568',
#   'LanguageCode': 'en',
#   'SKU': 'DI152D040-Q11',
#   'Text': 'Bad service!',
#   'Title': 'Wrong item sent.... Now Item is not in stock to reorder!'},
#  {'': '138600',
#   'LanguageCode': 'en',
#   'SKU': 'GS182A01N-K11',
#   'Text': 'Came quick once ordered , came as expected good quality and good packing',
#   'Title': 'Good product to and quick service would and have used the site to order more'},
#  {'': '138742',
#   'LanguageCode': 'en',
#   'SKU': 'HI121Q00G-Q11',
#   'Text': 'I&#39;m loving it ',
#   'Title': 'Highly recommended! '},
#  {'': '138823',
#   'LanguageCode': 'en',
#   'SKU': 'FAD11B001-K11',
#   'Text': 'Very comfortable and exactly the right colour. ',
#   'Title': 'It was great that I could get them in my size from you which I couldn&#39;t get elsewhere'},
#  {'': '138902',
#   'LanguageCode': 'en',
#   'SKU': 'WV021E00C-K11',
#   'Text': 'Gorgeous jacket, I&#39;m a sucker for light denim and this is no exception. Unique and perfect for warmer weather. I&#39;m giving it 4 rather than 5 stars as the tie&#x2F;belt is ridiculously long. Waven are obsessed with excess fabric, why??',
#   'Title': 'Love it! Had to cut belt though.'},
#  {'': '139011',
#   'LanguageCode': 'en',
#   'SKU': 'AD123G00S-A11',
#   'Text': 'perfect only i ordered the wrong size',
#   'Title': 'just what I wanted'},
#  {'': '139025',
#   'LanguageCode': 'en',
#   'SKU': 'R1922O05X-Q11',
#   'Text': 'Doesn&#39;t look anything like it does in the picture, plus the material is really thin, almost transparent!! ',
#   'Title': 'disappointed '},
#  {'': '139028',
#   'LanguageCode': 'en',
#   'SKU': 'HU721D029-H11',
#   'Text': 'quality fabric is key and this one has it. The fit and cut is just right although their sizing is fairly big so a UK size 8 is Hugo XS. Wear with black trousers or pencil skirt ',
#   'Title': 'Quality fabric and good workmanship'},
#  {'': '139029',
#   'LanguageCode': 'en',
#   'SKU': 'AD541D0GN-Q11',
#   'Text': 'Gym top ',
#   'Title': 'I really like this gym top, it&#39;s light gives coverage especially the chest area '},
#  {'': '139050',
#   'LanguageCode': 'en',
#   'SKU': 'P1422D01O-K11',
#   'Text': 'Hey',
#   'Title': 'Hi'},
#  {'': '139225',
#   'LanguageCode': 'en',
#   'SKU': 'WR121N01Q-K11',
#   'Text': 'sorry I do not like this style and fit of wrangler jeans   i will be returning this order as the jeans are too stretchy',
#   'Title': 'tina bootcut are my favourite sorry i used my discount code to order the above '},
#  {'': '139267',
#   'LanguageCode': 'en',
#   'SKU': 'P5782A01N-K11',
#   'Text': 'Great fit and stretchy material. Ideal for sport',
#   'Title': 'Comfie briefs'},
#  {'': '139496',
#   'LanguageCode': 'en',
#   'SKU': 'NM321K012-C11',
#   'Text': 'Poor finish!',
#   'Title': 'Various threads just left unfinished at end of seams, looks awful, had to finish it myself'},
#  {'': '139558',
#   'LanguageCode': 'en',
#   'SKU': 'TO721G02A-Q11',
#   'Text': 'Absolutely love it! Perfect fit and a great looking faux leather, looks like real leather actually. Had so many compliments wearing it.',
#   'Title': 'Great jacket! Excellent quality item!'},
#  {'': '139625',
#   'LanguageCode': 'en',
#   'SKU': 'PU122E00E-K11',
#   'Text': 'Nice model I&#39;m 178 cm tall and weighs 88 kilograms and ordered a size &quot;m&quot; fits me perfectly',
#   'Title': 'Good stuff and good cut'},
#  {'': '139663',
#   'LanguageCode': 'en',
#   'SKU': 'AD541A0ZH-K11',
#   'Text': 'The most comfortable shoes on the market. The boost sole is squishy under foot, soft to stand on all day &amp; the boost technology gives an everlasting spring to each step. There quite a good degree of heel to toe angle. There is some arch support which is fine for me but if you are looking for more arch support then the ultra boost ST models might be better. The sole is made from continental so traction is superior in all weather. The insoles are removable and do have an nmd type covering of the boost if you wish to remove them. All ultra boosts come with a torsion plate built into the sole, this helps with foot stability and arch stability. The upper is made from primeknit material, its super stretchy so there is no restriction to you feet at all, it has a sock like feel when the shoes are on feet, so much so you can forget you are wearing shoes! It is breathable but I do find my feet still get fairly hot inside these shoes. \nThe colour of this shoe is a mix between blue and grey, and it has black peppered in throughout the primeknit with a black heel cap, black continental sole and a semi translucent cage. It is a stunning shoe, so much so I bought two pairs. \nSizing - go true to size, do not size up as the primeknit upper is so stretchy the shoe will be too big. I&#39;m a UK 8.5 in women&#39;s and men&#39;s and the shoes fit perfectly, I can even fit an 8 quite happily due to the stretchy materials. Hope this helps',
#   'Title': 'The worlds most comfortable shoe!!'},
#  {'': '139672',
#   'LanguageCode': 'en',
#   'SKU': 'PO212B02Y-M11',
#   'Text': 'Another good pair of trainers   Great colour and size  \nArrived quickly and good price ',
#   'Title': 'Another good price from Zalando'},
#  {'': '139690',
#   'LanguageCode': 'en',
#   'SKU': 'AD122O08G-Q11',
#   'Text': 'Don&#39;t order this they send you a different top! It&#39;s not what it shows In the picture. Then you&#39;ll receive awful customer service to rectify it. ',
#   'Title': 'wrong t shirt bad customer service'},
#  {'': '139696',
#   'LanguageCode': 'en',
#   'SKU': 'VE121E0RJ-Q11',
#   'Text': 'Looks fantastic in picture but the material is cheap and looks cheap, so very disappointed',
#   'Title': 'Would not recommend it'},
#  {'': '139697',
#   'LanguageCode': 'en',
#   'SKU': 'TO722Q02X-A11',
#   'Text': 'Nice long sleeve top',
#   'Title': 'Comfortable, fits well and looks good'},
#  {'': '139704',
#   'LanguageCode': 'en',
#   'SKU': 'AD543A1JX-Q11',
#   'Text': 'Really nice smart and comfortable trainers.  My boy loves them. ',
#   'Title': 'Love them'},
#  {'': '139779',
#   'LanguageCode': 'en',
#   'SKU': '1VJ21C02V-H11',
#   'Text': 'Unfortunately the dress did not suit me ',
#   'Title': 'I sent the dress back '},
#  {'': '139819',
#   'LanguageCode': 'en',
#   'SKU': 'HU315B01W-N11',
#   'Text': 'I love Hummel trainers - they fit my feet really well and they&#39;re a bit different from the boring Nike&#x2F;Adidas ones that everyone else on the planet seems to wear. Just one issue with these ones - they&#39;re listed as &quot;pristine white&quot;, but they&#39;re not. They&#39;re actually a cream&#x2F;off-white colour, so the listing on here is a little misleading.',
#   'Title': 'Great trainers but Zalando needs to amend its description'},
#  {'': '139829',
#   'LanguageCode': 'en',
#   'SKU': 'DK124G00E-K11',
#   'Text': 'I&#39;ve returned this item before 2 days because the size doesn&#39;t fit but I didn&#39;t receive an email confirmation of receiving this item in your warehouse.\nThanks ',
#   'Title': 'The fabric is very good quality but size 10 is small to the age of 10 it fits 8 years '},
#  {'': '139870',
#   'LanguageCode': 'en',
#   'SKU': 'AI111I00E-K11',
#   'Text': 'Looks nice',
#   'Title': 'Very comfortable '},
#  {'': '140009',
#   'LanguageCode': 'en',
#   'SKU': 'AD121G04G-K11',
#   'Text': 'Happy about product exactly how it&#39;s described.Trandy , for someone who want something different ',
#   'Title': 'Super fast delivery,great service '},
#  {'': '140029',
#   'LanguageCode': 'en',
#   'SKU': 'AD541D0F4-A11',
#   'Text': 'Really like this top. Great fit and different.',
#   'Title': 'Definitely recommend this.'},
#  {'': '140255',
#   'LanguageCode': 'en',
#   'SKU': 'ME2-mzw-0004-99',
#   'Text': 'really, really good',
#   'Title': 'Looks great'},
#  {'': '140606',
#   'LanguageCode': 'en',
#   'SKU': 'FA1-yzw-0015-99',
#   'Text': 'all ok',
#   'Title': 'socks good- everything good'},
#  {'': '141257',
#   'LanguageCode': 'en',
#   'SKU': 'DI1-xza-0242-99',
#   'Text': "Well it's Diesel- so amazing……..a bit small",
#   'Title': 'Great'},
#  {'': '141480',
#   'LanguageCode': 'en',
#   'SKU': 'RE5-fza-0203-99',
#   'Text': 'i like this a lot, i want!!',
#   'Title': 'reebok'},
#  {'': '141647',
#   'LanguageCode': 'en',
#   'SKU': 'MA6-yzw-0002-99',
#   'Text': 'These jeans are amazing. I would recommend that others order their normal size and one size up - that\'s what I did. The larger ones were the right size for me…but it was a close call. Both looked great but my "normal" size really was a bit tight!',
#   'Title': 'Simply perfect!'},
#  {'': '141864',
#   'LanguageCode': 'en',
#   'SKU': 'SE6-xzw-0004-99',
#   'Text': 'speedy delivery, smooth ordering process',
#   'Title': 'first class'},
#  {'': '142183',
#   'LanguageCode': 'en',
#   'SKU': 'AD1-fzw-0206-99',
#   'Text': 'every thing was great, fast delivery, perfect fit, keep it up!',
#   'Title': 'fantastic all round'},
#  {'': '142278',
#   'LanguageCode': 'en',
#   'SKU': 'DO122B001-503',
#   'Text': 'great',
#   'Title': 'Chino'},
#  {'': '142521',
#   'LanguageCode': 'en',
#   'SKU': 'N1241D05R-A11',
#   'Text': 'Lovely and soft Nike top.\nWas surprised of soft the fabric is compared to my other Nike tops.\nPerfect fit.',
#   'Title': 'My favourite top!'},
#  {'': '142565',
#   'LanguageCode': 'en',
#   'SKU': 'EC1-fzw-0047-99',
#   'Text': 'Got a pair of these boots for my Christmas. They are fabulous! Very warm, comfortable and very stylish. Got to be one of the best pairs I have ever owned and I like my boots! Have quite a few pairs!!\r\nI would totally recommend these Ecco boots. Classic style. Excellent boot all round!',
#   'Title': 'Christmas boots.'},
#  {'': '142879',
#   'LanguageCode': 'en',
#   'SKU': 'AI2-uzw-0002-99',
#   'Text': '!',
#   'Title': 'Not too big, like most wellies!'},
#  {'': '143102',
#   'LanguageCode': 'en',
#   'SKU': 'LE221N00V-K13',
#   'Text': 'Too short so I had to send them back.  Shame as they are a nice looking pair of jeans.',
#   'Title': 'Too short.'},
#  {'': '143284',
#   'LanguageCode': 'en',
#   'SKU': 'SO211M012-Q11',
#   'Text': 'This was the first item what i ordered from Zalando. I can say I am really Satisfy. This boots are awsome...good quality...good size , perfect! ',
#   'Title': 'Perfect Item'},
#  {'': '143437',
#   'LanguageCode': 'en',
#   'SKU': 'ON321N065-Q11',
#   'Text': 'Jeans were ripped at the seam',
#   'Title': ','},
#  {'': '144748',
#   'LanguageCode': 'en',
#   'SKU': 'LA7-czw-0010-99',
#   'Text': 'only available online and not through retail shops',
#   'Title': 'quality product'},
#  {'': '145803',
#   'LanguageCode': 'en',
#   'SKU': 'LA212B079-Q11',
#   'Text': 'Nice trainers at a good price delivered swiftly thanks',
#   'Title': 'Lacoste trainers'},
#  {'': '146242',
#   'LanguageCode': 'en',
#   'SKU': 'MA321H02D-K11',
#   'Text': 'This coat is light for its chunky size, warm and of good quality.',
#   'Title': 'Overall very happy with this purchase!'},
#  {'': '146550',
#   'LanguageCode': 'en',
#   'SKU': 'GA712A003-304',
#   'Text': 'i like this article size 37 (EU) if its posible.Thanks"     (00447405210016)',
#   'Title': 'I like'},
#  {'': '146796',
#   'LanguageCode': 'en',
#   'SKU': 'HM181B05Y-G11',
#   'Text': 'It is beautifully made and very comfortable to wear',
#   'Title': 'My Nightie'},
#  {'': '146968',
#   'LanguageCode': 'en',
#   'SKU': 'AN611MA0S-Q11',
#   'Text': "These are not over the knee boots. The height comes to just below the knee. They also don't look like good quality ",
#   'Title': 'Disappointing'},
#  {'': '147200',
#   'LanguageCode': 'en',
#   'SKU': 'TT741FA01-C11',
#   'Text': 'nice jacket, ordered a 16, felt more like a 12, very small made, returned',
#   'Title': 'too small'},
#  {'': '147668',
#   'LanguageCode': 'en',
#   'SKU': 'LE511D00B-708',
#   'Text': 'Nice pair of sandals but was too small for me.',
#   'Title': 'Small fitting'},
#  {'': '147842',
#   'LanguageCode': 'en',
#   'SKU': 'SZ454H00E-O11',
#   'Text': ' Good leather and it will not take long for it to be butter soft and nicely squelchy. Looks great with casual clothes.',
#   'Title': 'Love it'},
#  {'': '147865',
#   'LanguageCode': 'en',
#   'SKU': 'CL111C00O-G11',
#   'Text': "best shoe of this style I've ever worn",
#   'Title': 'Glove like'},
#  {'': '148134',
#   'LanguageCode': 'en',
#   'SKU': 'ZA821D01Q-Q11',
#   'Text': 'Fits well and looks good',
#   'Title': 'Looks good'},
#  {'': '148415',
#   'LanguageCode': 'en',
#   'SKU': 'OM131B003-918',
#   'Text': "Fantastic product, iv'e only used this a couple of times and already i can see the difference it's making.  My skin feels incredible it's really soft and moisturised and their are absolutely no shaving nicks or bumps on the skin, also my skins appearance has improved greatly no red rashes and reduces post acne marks.  Brilliant.",
#   'Title': 'The Best Shave'},
#  {'': '148601',
#   'LanguageCode': 'en',
#   'SKU': 'VE121I01H-502',
#   'Text': "The picture doesn't do much justice to this lovely dress that is now my absolute favourite! It is so feminine, fits my figure perfectly (and it's so nice to have size 8 really fitting size 8, not 12) and   is just a joy to wear. Considering the price, it's just a treasure...",
#   'Title': 'Loving it!'},
#  {'': '148795',
#   'LanguageCode': 'en',
#   'SKU': 'N1243A0EU-Q11',
#   'Text': 'My son enjoys the trainers says they are light and comfortable',
#   'Title': 'Good fit'},
#  {'': '148925',
#   'LanguageCode': 'en',
#   'SKU': 'VE321D00C-704',
#   'Text': "The Jacket it's not so comfortable, the leather is too thick and you feel like you're wearing cupboard. Because the price is so high, I would give 3*s overall.",
#   'Title': 'not too comfortable'},
#  {'': '149265',
#   'LanguageCode': 'en',
#   'SKU': 'TL131A052-401',
#   'Text': "This lipstick is lovely and the colour is really vibrant.\r\nI would recommend purchasing it, and at the reduced price it's a real bargain.",
#   'Title': 'Lovely Lipstick'},
#  {'': '149326',
#   'LanguageCode': 'en',
#   'SKU': 'LA211D00C-002',
#   'Text': 'Good looking and comfortable flip flops which arrived quickly after ordering.',
#   'Title': 'Lacoste Flip Flops'},
#  {'': '149933',
#   'LanguageCode': 'en',
#   'SKU': 'MI311Z00O-305',
#   'Text': 'Very nice shoes, they look really nice on the leg.',
#   'Title': 'I recommend these shoes'},
#  {'': '149960',
#   'LanguageCode': 'en',
#   'SKU': 'AD112B01C-002',
#   'Text': 'Sent american size 11 instead of UK 11 with NO returns slip, am very very disappointed !!!',
#   'Title': 'Wrong size'},
#  {'': '149966',
#   'LanguageCode': 'en',
#   'SKU': 'AD112B01F-002',
#   'Text': 'lovely pair of trainers and although they looked tight,surprisingly very comfy. also come with spare laces 4 a bit of customization.',
#   'Title': 'happy feet'},
#  ...]
